# %%
import re
import random
data_path = "English.txt"
data_path2 = "Hindi.txt"
# Defining lines as a list of each line
with open(data_path, 'r', encoding='utf-8') as f:
  lines = f.read().strip().split('\n')
with open(data_path2, 'r', encoding='utf-8') as f:
  lines2 = f.read().strip().split('\n')

lines = [" ".join(re.findall(r"[A-Za-z0-9]+",line)) for line in lines]
lines2 = [re.sub(r"%s|\(|\)|<|>|%|[a-z]|[A-Z]|_",'',line) for line in lines2]

# Grouping lines by response pair
pairs = list(zip(lines,lines2))
random.shuffle(pairs)
print(len(pairs))
# Out:
# 10000

# %%
print(pairs[103])
# Out:
# ('they like pears apples and mangoes', 'वे नाशपाती, सेब और आम पसंद करते हैं।')

# %%
import numpy as np

input_docs = []
target_docs = []
input_tokens = set()
target_tokens = set()
for line in pairs:
  input_doc, target_doc = line[0], line[1]
  # Appending each input sentence to input_docs
  input_docs.append(input_doc)
  # Splitting words from punctuation  
  target_doc = " ".join(re.findall(r"[\w']+|[^\s\w]", target_doc))
  # Redefine target_doc below and append it to target_docs
  target_doc = ' ' + target_doc + ' '
  target_docs.append(target_doc)
  
  # Now we split up each sentence into words and add each unique word to our vocabulary set
  for token in re.findall(r"[\w']+|[^\s\w]", input_doc):
    if token not in input_tokens:
      input_tokens.add(token)
  for token in target_doc.split(" "):
    if token not in target_tokens:
      target_tokens.add(token)
input_tokens = sorted(list(input_tokens))
target_tokens = sorted(list(target_tokens))
num_encoder_tokens = len(input_tokens)
num_decoder_tokens = len(target_tokens)

input_features_dict = dict(
    [(token, i) for i, token in enumerate(input_tokens)])
target_features_dict = dict(
    [(token, i) for i, token in enumerate(target_tokens)])

reverse_input_features_dict = dict(
    (i, token) for token, i in input_features_dict.items())
reverse_target_features_dict = dict(
    (i, token) for token, i in target_features_dict.items())


max_encoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", input_doc)) for input_doc in input_docs])
max_decoder_seq_length = max([len(re.findall(r"[\w']+|[^\s\w]", target_doc)) for target_doc in target_docs])

encoder_input_data = np.zeros(
    (len(input_docs), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_docs), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for line, (input_doc, target_doc) in enumerate(zip(input_docs, target_docs)):
    for timestep, token in enumerate(re.findall(r"[\w']+|[^\s\w]", input_doc)):
        #Assign 1. for the current line, timestep, & word in encoder_input_data
        encoder_input_data[line, timestep, input_features_dict[token]] = 1.
    
    for timestep, token in enumerate(target_doc.split()):
        decoder_input_data[line, timestep, target_features_dict[token]] = 1.
        if timestep > 0:
            decoder_target_data[line, timestep - 1, target_features_dict[token]] = 1.

# %%
print(target_docs[103],input_docs[103],num_decoder_tokens,num_encoder_tokens)
# Out:
#  भ ा रत मई क े द ौ र ा न कभ ी व ् यस ् त नह ी ं ह ै , और यह ज ु ल ा ई म े ं बर ् फ ी ल ा ह ै ।  india is never busy during may and it is snowy in july 237 200

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model
#Dimensionality
dimensionality = 256
#The batch size and number of epochs
batch_size = 256
epochs = 100
#Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder_lstm = LSTM(dimensionality, return_state=True)
encoder_outputs, state_hidden, state_cell = encoder_lstm(encoder_inputs)
encoder_states = [state_hidden, state_cell]
#Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(dimensionality, return_sequences=True, return_state=True)
decoder_outputs, decoder_state_hidden, decoder_state_cell = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# #Model
training_model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
# #Compiling
training_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#Training
history = training_model.fit([encoder_input_data, decoder_input_data], decoder_target_data, batch_size = batch_size, epochs = epochs, validation_split = 0.2)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 69s 2s/step - loss: 2.4745 - accuracy: 0.0436 - val_loss: 2.2015 - val_accuracy: 0.0443
# Epoch 2/100
# 32/32 [==============================] - 50s 2s/step - loss: 2.2025 - accuracy: 0.0451 - val_loss: 2.2065 - val_accuracy: 0.0425
# Epoch 3/100
# 32/32 [==============================] - 51s 2s/step - loss: 2.1962 - accuracy: 0.0457 - val_loss: 2.1962 - val_accuracy: 0.0475
# Epoch 4/100
# 32/32 [==============================] - 51s 2s/step - loss: 2.1878 - accuracy: 0.0480 - val_loss: 2.1859 - val_accuracy: 0.0509
# Epoch 5/100
# 32/32 [==============================] - 53s 2s/step - loss: 2.1751 - accuracy: 0.0519 - val_loss: 2.1751 - val_accuracy: 0.0552
# Epoch 6/100
# 32/32 [==============================] - 52s 2s/step - loss: 2.1626 - accuracy: 0.0546 - val_loss: 2.1644 - val_accuracy: 0.0566
# Epoch 7/100
# 32/32 [==============================] - 55s 2s/step - loss: 2.1545 - accuracy: 0.0579 - val_loss: 2.1568 - val_accuracy: 0.0615
# Epoch 8/100
# 32/32 [==============================] - 53s 2s/step - loss: 2.1489 - accuracy: 0.0606 - val_loss: 2.1494 - val_accuracy: 0.0627
# Epoch 9/100
# 32/32 [==============================] - 56s 2s/step - loss: 2.1366 - accuracy: 0.0626 - val_loss: 2.1288 - val_accuracy: 0.0639
# Epoch 10/100
# 32/32 [==============================] - 48s 2s/step - loss: 2.1106 - accuracy: 0.0667 - val_loss: 2.1066 - val_accuracy: 0.0692
# Epoch 11/100
# 32/32 [==============================] - 59s 2s/step - loss: 2.0835 - accuracy: 0.0707 - val_loss: 2.0783 - val_accuracy: 0.0721
# Epoch 12/100
# 32/32 [==============================] - 58s 2s/step - loss: 2.0627 - accuracy: 0.0733 - val_loss: 2.0613 - val_accuracy: 0.0774
# Epoch 13/100
# 32/32 [==============================] - 61s 2s/step - loss: 2.0368 - accuracy: 0.0813 - val_loss: 2.0296 - val_accuracy: 0.0849
# Epoch 14/100
# 32/32 [==============================] - 60s 2s/step - loss: 2.0134 - accuracy: 0.0882 - val_loss: 2.0083 - val_accuracy: 0.0898
# Epoch 15/100
# 32/32 [==============================] - 57s 2s/step - loss: 1.9964 - accuracy: 0.0900 - val_loss: 1.9886 - val_accuracy: 0.0900
# Epoch 16/100
# 32/32 [==============================] - 53s 2s/step - loss: 1.9753 - accuracy: 0.0929 - val_loss: 1.9681 - val_accuracy: 0.0939
# Epoch 17/100
# 32/32 [==============================] - 55s 2s/step - loss: 1.9512 - accuracy: 0.1005 - val_loss: 1.9451 - val_accuracy: 0.1027
# Epoch 18/100
# 32/32 [==============================] - 50s 2s/step - loss: 1.9293 - accuracy: 0.1095 - val_loss: 1.9300 - val_accuracy: 0.1155
# Epoch 19/100
# 32/32 [==============================] - 56s 2s/step - loss: 1.9074 - accuracy: 0.1180 - val_loss: 1.8997 - val_accuracy: 0.1222
# Epoch 20/100
# 32/32 [==============================] - 52s 2s/step - loss: 1.8800 - accuracy: 0.1290 - val_loss: 1.8698 - val_accuracy: 0.1372
# Epoch 21/100
# 32/32 [==============================] - 53s 2s/step - loss: 1.8506 - accuracy: 0.1398 - val_loss: 1.8566 - val_accuracy: 0.1442
# Epoch 22/100
# 32/32 [==============================] - 52s 2s/step - loss: 1.8353 - accuracy: 0.1448 - val_loss: 1.8115 - val_accuracy: 0.1564
# Epoch 23/100
# 32/32 [==============================] - 56s 2s/step - loss: 1.7876 - accuracy: 0.1633 - val_loss: 1.7682 - val_accuracy: 0.1730
# Epoch 24/100
# 32/32 [==============================] - 54s 2s/step - loss: 1.7427 - accuracy: 0.1819 - val_loss: 1.7184 - val_accuracy: 0.1947
# Epoch 25/100
# 32/32 [==============================] - 54s 2s/step - loss: 1.6936 - accuracy: 0.1956 - val_loss: 1.6709 - val_accuracy: 0.2040
# Epoch 26/100
# 32/32 [==============================] - 54s 2s/step - loss: 1.6492 - accuracy: 0.2074 - val_loss: 1.6243 - val_accuracy: 0.2163
# Epoch 27/100
# 32/32 [==============================] - 52s 2s/step - loss: 1.5950 - accuracy: 0.2243 - val_loss: 1.5713 - val_accuracy: 0.2366
# Epoch 28/100
# 32/32 [==============================] - 52s 2s/step - loss: 1.5352 - accuracy: 0.2458 - val_loss: 1.5062 - val_accuracy: 0.2568
# Epoch 29/100
# 32/32 [==============================] - 53s 2s/step - loss: 1.4806 - accuracy: 0.2630 - val_loss: 1.4580 - val_accuracy: 0.2743
# Epoch 30/100
# 32/32 [==============================] - 51s 2s/step - loss: 1.4259 - accuracy: 0.2780 - val_loss: 1.3996 - val_accuracy: 0.2846
# Epoch 31/100
# 32/32 [==============================] - 55s 2s/step - loss: 1.3704 - accuracy: 0.2873 - val_loss: 1.3459 - val_accuracy: 0.2958
# Epoch 32/100
# 32/32 [==============================] - 49s 2s/step - loss: 1.3169 - accuracy: 0.2983 - val_loss: 1.2873 - val_accuracy: 0.3056
# Epoch 33/100
# 32/32 [==============================] - 51s 2s/step - loss: 1.2570 - accuracy: 0.3123 - val_loss: 1.2335 - val_accuracy: 0.3184
# Epoch 34/100
# 32/32 [==============================] - 53s 2s/step - loss: 1.2081 - accuracy: 0.3246 - val_loss: 1.1927 - val_accuracy: 0.3312
# Epoch 35/100
# 32/32 [==============================] - 50s 2s/step - loss: 1.1554 - accuracy: 0.3398 - val_loss: 1.1346 - val_accuracy: 0.3467
# Epoch 36/100
# 32/32 [==============================] - 52s 2s/step - loss: 1.1029 - accuracy: 0.3548 - val_loss: 1.0847 - val_accuracy: 0.3604
# Epoch 37/100
# 32/32 [==============================] - 50s 2s/step - loss: 1.0535 - accuracy: 0.3671 - val_loss: 1.0306 - val_accuracy: 0.3752
# Epoch 38/100
# 32/32 [==============================] - 52s 2s/step - loss: 1.0091 - accuracy: 0.3771 - val_loss: 0.9930 - val_accuracy: 0.3823
# Epoch 39/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.9598 - accuracy: 0.3889 - val_loss: 0.9417 - val_accuracy: 0.3952
# Epoch 40/100
# 32/32 [==============================] - 59s 2s/step - loss: 0.9152 - accuracy: 0.3987 - val_loss: 0.8957 - val_accuracy: 0.4049
# Epoch 41/100
# 32/32 [==============================] - 58s 2s/step - loss: 0.8754 - accuracy: 0.4065 - val_loss: 0.8548 - val_accuracy: 0.4128
# Epoch 42/100
# 32/32 [==============================] - 54s 2s/step - loss: 0.8400 - accuracy: 0.4126 - val_loss: 0.8220 - val_accuracy: 0.4192
# Epoch 43/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.8008 - accuracy: 0.4202 - val_loss: 0.7871 - val_accuracy: 0.4247
# Epoch 44/100
# 32/32 [==============================] - 53s 2s/step - loss: 0.7667 - accuracy: 0.4263 - val_loss: 0.7630 - val_accuracy: 0.4292
# Epoch 45/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.7370 - accuracy: 0.4313 - val_loss: 0.7329 - val_accuracy: 0.4331
# Epoch 46/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.7085 - accuracy: 0.4365 - val_loss: 0.7002 - val_accuracy: 0.4383
# Epoch 47/100
# 32/32 [==============================] - 55s 2s/step - loss: 0.6816 - accuracy: 0.4411 - val_loss: 0.6822 - val_accuracy: 0.4422
# Epoch 48/100
# 32/32 [==============================] - 50s 2s/step - loss: 0.6611 - accuracy: 0.4442 - val_loss: 0.6555 - val_accuracy: 0.4475
# Epoch 49/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.6368 - accuracy: 0.4484 - val_loss: 0.6351 - val_accuracy: 0.4495
# Epoch 50/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.6137 - accuracy: 0.4525 - val_loss: 0.6142 - val_accuracy: 0.4544
# Epoch 51/100
# 32/32 [==============================] - 57s 2s/step - loss: 0.5937 - accuracy: 0.4564 - val_loss: 0.5901 - val_accuracy: 0.4589
# Epoch 52/100
# 32/32 [==============================] - 55s 2s/step - loss: 0.5764 - accuracy: 0.4602 - val_loss: 0.5731 - val_accuracy: 0.4613
# Epoch 53/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.5599 - accuracy: 0.4633 - val_loss: 0.5566 - val_accuracy: 0.4655
# Epoch 54/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.5446 - accuracy: 0.4671 - val_loss: 0.5433 - val_accuracy: 0.4679
# Epoch 55/100
# 32/32 [==============================] - 55s 2s/step - loss: 0.5302 - accuracy: 0.4701 - val_loss: 0.5304 - val_accuracy: 0.4722
# Epoch 56/100
# 32/32 [==============================] - 50s 2s/step - loss: 0.5171 - accuracy: 0.4737 - val_loss: 0.5242 - val_accuracy: 0.4756
# Epoch 57/100
# 32/32 [==============================] - 53s 2s/step - loss: 0.5055 - accuracy: 0.4785 - val_loss: 0.5067 - val_accuracy: 0.4758
# Epoch 58/100
# 32/32 [==============================] - 50s 2s/step - loss: 0.4947 - accuracy: 0.4819 - val_loss: 0.5058 - val_accuracy: 0.4816
# Epoch 59/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.4836 - accuracy: 0.4855 - val_loss: 0.4885 - val_accuracy: 0.4860
# Epoch 60/100
# 32/32 [==============================] - 53s 2s/step - loss: 0.4723 - accuracy: 0.4882 - val_loss: 0.4777 - val_accuracy: 0.4883
# Epoch 61/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.4631 - accuracy: 0.4899 - val_loss: 0.4686 - val_accuracy: 0.4898
# Epoch 62/100
# 32/32 [==============================] - 53s 2s/step - loss: 0.4622 - accuracy: 0.4891 - val_loss: 0.4693 - val_accuracy: 0.4863
# Epoch 63/100
# 32/32 [==============================] - 53s 2s/step - loss: 0.4540 - accuracy: 0.4899 - val_loss: 0.4571 - val_accuracy: 0.4897
# Epoch 64/100
# 32/32 [==============================] - 54s 2s/step - loss: 0.4438 - accuracy: 0.4921 - val_loss: 0.4465 - val_accuracy: 0.4925
# Epoch 65/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.4338 - accuracy: 0.4941 - val_loss: 0.4449 - val_accuracy: 0.4932
# Epoch 66/100
# 32/32 [==============================] - 54s 2s/step - loss: 0.4276 - accuracy: 0.4950 - val_loss: 0.4319 - val_accuracy: 0.4949
# Epoch 67/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.4183 - accuracy: 0.4969 - val_loss: 0.4258 - val_accuracy: 0.4960
# Epoch 68/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.4129 - accuracy: 0.4979 - val_loss: 0.4258 - val_accuracy: 0.4968
# Epoch 69/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.4069 - accuracy: 0.4989 - val_loss: 0.4133 - val_accuracy: 0.4979
# Epoch 70/100
# 32/32 [==============================] - 60s 2s/step - loss: 0.4000 - accuracy: 0.5001 - val_loss: 0.4073 - val_accuracy: 0.4993
# Epoch 71/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.3957 - accuracy: 0.5008 - val_loss: 0.4056 - val_accuracy: 0.5002
# Epoch 72/100
# 32/32 [==============================] - 55s 2s/step - loss: 0.3902 - accuracy: 0.5020 - val_loss: 0.4151 - val_accuracy: 0.4986
# Epoch 73/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.3869 - accuracy: 0.5025 - val_loss: 0.3973 - val_accuracy: 0.5009
# Epoch 74/100
# 32/32 [==============================] - 56s 2s/step - loss: 0.3816 - accuracy: 0.5035 - val_loss: 0.3945 - val_accuracy: 0.5017
# Epoch 75/100
# 32/32 [==============================] - 58s 2s/step - loss: 0.3756 - accuracy: 0.5047 - val_loss: 0.3845 - val_accuracy: 0.5040
# Epoch 76/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.3703 - accuracy: 0.5058 - val_loss: 0.3822 - val_accuracy: 0.5041
# Epoch 77/100
# 32/32 [==============================] - 56s 2s/step - loss: 0.3656 - accuracy: 0.5066 - val_loss: 0.3760 - val_accuracy: 0.5051
# Epoch 78/100
# 32/32 [==============================] - 53s 2s/step - loss: 0.3616 - accuracy: 0.5072 - val_loss: 0.3784 - val_accuracy: 0.5045
# Epoch 79/100
# 32/32 [==============================] - 48s 2s/step - loss: 0.3588 - accuracy: 0.5077 - val_loss: 0.3728 - val_accuracy: 0.5055
# Epoch 80/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.3539 - accuracy: 0.5086 - val_loss: 0.3680 - val_accuracy: 0.5066
# Epoch 81/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.3501 - accuracy: 0.5092 - val_loss: 0.3653 - val_accuracy: 0.5075
# Epoch 82/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.3501 - accuracy: 0.5090 - val_loss: 0.3584 - val_accuracy: 0.5081
# Epoch 83/100
# 32/32 [==============================] - 56s 2s/step - loss: 0.3437 - accuracy: 0.5102 - val_loss: 0.3577 - val_accuracy: 0.5078
# Epoch 84/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.3396 - accuracy: 0.5109 - val_loss: 0.3517 - val_accuracy: 0.5090
# Epoch 85/100
# 32/32 [==============================] - 50s 2s/step - loss: 0.3370 - accuracy: 0.5114 - val_loss: 0.3517 - val_accuracy: 0.5090
# Epoch 86/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.3335 - accuracy: 0.5121 - val_loss: 0.3478 - val_accuracy: 0.5097
# Epoch 87/100
# 32/32 [==============================] - 56s 2s/step - loss: 0.3315 - accuracy: 0.5123 - val_loss: 0.3518 - val_accuracy: 0.5081
# Epoch 88/100
# 32/32 [==============================] - 50s 2s/step - loss: 0.3339 - accuracy: 0.5114 - val_loss: 0.3468 - val_accuracy: 0.5091
# Epoch 89/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.3263 - accuracy: 0.5129 - val_loss: 0.3412 - val_accuracy: 0.5105
# Epoch 90/100
# 32/32 [==============================] - 49s 2s/step - loss: 0.3210 - accuracy: 0.5143 - val_loss: 0.3498 - val_accuracy: 0.5086
# Epoch 91/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.3211 - accuracy: 0.5140 - val_loss: 0.3355 - val_accuracy: 0.5111
# Epoch 92/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.3165 - accuracy: 0.5150 - val_loss: 0.3292 - val_accuracy: 0.5123
# Epoch 93/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.3140 - accuracy: 0.5156 - val_loss: 0.3313 - val_accuracy: 0.5120
# Epoch 94/100
# 32/32 [==============================] - 56s 2s/step - loss: 0.3108 - accuracy: 0.5163 - val_loss: 0.3287 - val_accuracy: 0.5124
# Epoch 95/100
# 32/32 [==============================] - 54s 2s/step - loss: 0.3088 - accuracy: 0.5165 - val_loss: 0.3275 - val_accuracy: 0.5131
# Epoch 96/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.3054 - accuracy: 0.5171 - val_loss: 0.3230 - val_accuracy: 0.5135
# Epoch 97/100
# 32/32 [==============================] - 52s 2s/step - loss: 0.3024 - accuracy: 0.5179 - val_loss: 0.3220 - val_accuracy: 0.5138
# Epoch 98/100
# 32/32 [==============================] - 51s 2s/step - loss: 0.3006 - accuracy: 0.5181 - val_loss: 0.3216 - val_accuracy: 0.5139
# Epoch 99/100
# 32/32 [==============================] - 57s 2s/step - loss: 0.3034 - accuracy: 0.5173 - val_loss: 0.3235 - val_accuracy: 0.5131
# Epoch 100/100
# 32/32 [==============================] - 55s 2s/step - loss: 0.3030 - accuracy: 0.5173 - val_loss: 0.3224 - val_accuracy: 0.5129

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.savefig('wordA.png')
plt.figure()
plt.show()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'o', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.savefig('wordL.png')
plt.figure()
plt.show()

# %%
from tensorflow import keras
from keras.models import load_model
from keras.layers import Input, LSTM, Dense
from keras.models import Model
encoder_inputs = training_model.input[0]
encoder_outputs, state_h_enc, state_c_enc = training_model.layers[2].output
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

latent_dim = 256
decoder_state_input_hidden = Input(shape=(latent_dim,))
decoder_state_input_cell = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_hidden, decoder_state_input_cell]
decoder_outputs, state_hidden, state_cell = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_hidden, state_cell]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

def decode_response(test_input):
    #Getting the output states to pass into the decoder
    states_value = encoder_model.predict(test_input)
    #Generating empty target sequence of length 1
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    #Setting the first token of target sequence with the start token
    target_seq[0, 0, target_features_dict['']] = 1.
    
    #A variable to store our response word by word
    decoded_sentence = ''
    
    stop_condition = False
    while not stop_condition:
      #Predicting output tokens with probabilities and states
      output_tokens, hidden_state, cell_state = decoder_model.predict([target_seq] + states_value)
#Choosing the one with highest probability
      sampled_token_index = np.argmax(output_tokens[0, -1, :])
      sampled_token = reverse_target_features_dict[sampled_token_index]
      decoded_sentence += " " + sampled_token
#Stop if hit max length or found the stop token
      if (sampled_token == '' or len(decoded_sentence) > max_decoder_seq_length):
        stop_condition = True
#Update the target sequence
      target_seq = np.zeros((1, 1, num_decoder_tokens))
      target_seq[0, 0, sampled_token_index] = 1.
      #Update states
      states_value = [hidden_state, cell_state]
    return decoded_sentence

# %%
class Translator:
  exit_commands = ("quit", "pause", "exit", "goodbye", "bye", "later", "stop")
  
  #Method to start the translator
  def start(self):
    user_response = input("Give in an English sentence. :) \n")
    self.translate(user_response)
  
  #Method to handle the conversation
  def translate(self, reply):
    while not self.make_exit(reply):
      reply = input(self.generate_response(reply)+"\n")

  #Method to convert user input into a matrix
  def string_to_matrix(self, user_input):
    tokens = re.findall(r"[\w']+|[^\s\w]", user_input)
    user_input_matrix = np.zeros(
      (1, max_encoder_seq_length, num_encoder_tokens),
      dtype='float32')
    for timestep, token in enumerate(tokens):
      if token in input_features_dict:
        user_input_matrix[0, timestep, input_features_dict[token]] = 1.
    return user_input_matrix
  
  #Method that will create a response using seq2seq model we built
  def generate_response(self, user_input):
    input_matrix = self.string_to_matrix(user_input)
    chatbot_response = decode_response(input_matrix)
    #Remove  and  tokens from chatbot_response
    chatbot_response = chatbot_response.replace("",'')
    chatbot_response = chatbot_response.replace("",'')
    return chatbot_response
  
  #Method to check for exit commands
  def make_exit(self, reply):
    for exit_command in self.exit_commands:
      if exit_command in reply:
        print("Ok, have a great day!")
        return True
    return False
  
translator = Translator()

# %%
translator.start()
# Out:
# Give in an English sentence. :)
# i like grapes , pears , and strawberries
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  ु झ े अ ं ग ू र , न ी ब ू और अ ं ग ू र पस ं द करत ा ह ै । ी ी ी ी ी ी ी ी ी ी ी
# exit
# Ok, have a great day!
